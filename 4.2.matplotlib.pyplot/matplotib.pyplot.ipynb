# %% [markdown]
# # **MATPLOTLIB.PYPLOT**
# # key : plt.inbuiltfunction(parameters)
# # 1.pyplot is mainly intended for interactive plots
# # 2.pylab combines pyplot with numpy into a single namespace.
# [matplotlib.pyplot](https://matplotlib.org/3.1.1/Matplotlib.pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig=plt.figure() # an empty figure with no axes
fig.suptitle('no axes on this figure')# Add a title so we know which it is
fig,ax_lst=plt.subplots(2,2)# row=2,column=2..a figure with a 2x2 grid of Axes

# %% [markdown]
# # C=Creat Graph

# %% [markdown]
# #Types of inputs to plotting functions
# plt.plot(x,y)
# *   Types of inputs to plotting functions
# *   All of plotting functions expect np.array or np.ma.masked_array as input.
# *   best to convert these to np.array objects prior to plotting.
# *   **so np.array ma convert garni data lai**

# %%
a=pd.DataFrame(np.random.rand(4,5),columns=list('ABCDE'))
a.values #dataframe bata values lai matra linxa
a_asarray=a.values

# %%
b=np.matrix([[1,2],[3,4]])
b_asarry=np.asarray(b) #convert input into array

# %%
x=np.linspace(0,2,100)
plt.plot(x,x, label='linear') 
plt.plot(x,x**2, label='quadratic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('simple plot')
plt.show()

# %%
x=np.arange(0,10,0.2)
y=np.sin(x)
fig,ax=plt.subplots()
ax.plot(x,y)
plt.show()
